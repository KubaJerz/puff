# %%
import json
import numpy as np
import os
import torch
import toml
import pandas as pd

# %%
# DEF CONSTATS

LABELS_PATH = "/home/kuba/projects/puff/paper00/experiments/01/data/smoking_labels_export_2025-07-15_22.json"
TRAIN_PERCENT = 0.8
DEV_PERCENT = 0.2
TEST_PERCENT = 0 if (TRAIN_PERCENT + DEV_PERCENT == 1) else (1 - TRAIN_PERCENT - DEV_PERCENT)
RANDOM_SEED = 70
USE_GYRO = False
LABEL = {"puff", "puffs"}
LABEL_VALUE = 1 #what to place in the y vector 
RESAMPLE = False
PERCENT_OF_NEGATIVE_WINDOWS_TO_SAMPLE = 0.8 #from all windows that don't contain a label what percent to sample
THRESHOLD_FOR_GAP = 30 #min
SAVE_DIR = '/home/kuba/projects/puff/paper00/experiments/02/data'
WINDOW_SIZE = 512
STEP_SIZE = WINDOW_SIZE 


train_sessions = []
dev_sessions = []
test_sessions = []

# %%
def save_config():
    """save experiment configuration to toml file"""
    config = {
        "paths": {
            "labels_path": LABELS_PATH,
            "save_dir": SAVE_DIR,
        },
        "experiment": {
            "label": LABEL,
            "resample": RESAMPLE,
            "random_seed": RANDOM_SEED,
            "window_size": WINDOW_SIZE,
            "step_size": STEP_SIZE,
            "percent_negative_windows": PERCENT_OF_NEGATIVE_WINDOWS_TO_SAMPLE,
            "threshold_gap_minutes": THRESHOLD_FOR_GAP,
            "use_gyro": USE_GYRO
        },
        "split": {
            "train_percent": TRAIN_PERCENT,
            "dev_percent": DEV_PERCENT,
            "test_percent": TEST_PERCENT,
        },
        "splits": {
            "train_sessions": train_sessions,
            "dev_essions": dev_sessions,
            "test_sessions": test_sessions 
        }
    }
    
    os.makedirs(SAVE_DIR, exist_ok=True)
    with open(os.path.join(SAVE_DIR, 'data_config.toml'), "w") as f:
        toml.dump(config, f)

# %%
def validate_splits():
    """makesure  dataset splits add up to 1.0"""
    if abs(TRAIN_PERCENT + DEV_PERCENT + TEST_PERCENT - 1.0) > 1e-6:
        raise ValueError(f"dataset % must add up to 1, not {TRAIN_PERCENT + DEV_PERCENT + TEST_PERCENT}")

# %%
def resample(df) :
    """resample dataframe to consistent sampling rate"""
    print("RESAMPLE has not been added yet so you need to impliment the function")
    raise RuntimeError("The resample function has not been implimented ")
    return df

# %%
def check_for_gaps(df):
    """split dataframe on time gaps larger than threshold"""
    gap_threshold_ns = THRESHOLD_FOR_GAP * 60 * 1_000_000_000
    df = df.sort_values('ns_since_reboot').reset_index(drop=True)
    time_diffs = df['ns_since_reboot'].diff()
    gap_indices = time_diffs[time_diffs > gap_threshold_ns].index
    
    if len(gap_indices) == 0:
        return [df]
    
    # split into segments
    segments = []
    start_idx = 0
    
    for gap_idx in gap_indices:
        if start_idx < gap_idx:
            segment = df.iloc[start_idx:gap_idx].copy()
            if not segment.empty:
                segments.append(segment)
        start_idx = gap_idx
    
    # add final segment
    if start_idx < len(df):
        final_segment = df.iloc[start_idx:].copy()
        if not final_segment.empty:
            segments.append(final_segment)
    
    return segments

# %%
def rename_df(df, type):
    if set(['ns_since_reboot', 'x', 'y', 'z']).issubset(set(df.columns)):
        df = df.rename(columns={"x": f"x_{type}", "y": f"y_{type}", "z": f"z_{type}"})
    elif set(['ns_since_reboot', f'{type}_x', f'{type}_y', f'{type}_z']).issubset(set(df.columns)):
        df = df.rename(columns={f"{type}_x": f"x_{type}", f"{type}_y": f"y_{type}", f"{type}_z": f"z_{type}"})
    else:   
        # rename columns to avoid conflicts
        raise ValueError(f"Warning coloumn names are: {df.columns} but expected to be: ['ns_since_reboot', 'x', 'y', 'z']")
    
    return df

# %%
def combine(session, project_path: str) -> pd.DataFrame:
    """combine accelerometer and gyroscope data for a session"""
    data_path = os.path.join(project_path, session['session_name'])
    
    try:
        accl = pd.read_csv(os.path.join(data_path, 'accelerometer_data.csv'))
        if USE_GYRO:
            gyro = pd.read_csv(os.path.join(data_path, 'gyroscope_data.csv'))
    except FileNotFoundError as e:
        print(f"Warning: Could not find data files for session {session['session_name']}: {e}")
        return pd.DataFrame()
    
    accl = rename_df(accl, type='accel')

    # ensure data types are correct
    for col in ['ns_since_reboot', 'x_accel', 'y_accel', 'z_accel']:
        accl[col] = accl[col].astype(float)
    
    if USE_GYRO:
        gyro = rename_df(gyro, type='gyro')
        
        # combine accelerometer and gyroscope data
        combined = pd.merge(accl, gyro, on='ns_since_reboot', how='inner')
        column_order = ['ns_since_reboot', 'x_accel', 'y_accel', 'z_accel', 'x_gyro', 'y_gyro', 'z_gyro']
    else:
        # use only accelerometer data
        combined = accl
        column_order = ['ns_since_reboot', 'x_accel', 'y_accel', 'z_accel']
    
    # reorder columns
    combined = combined[column_order]
    
    return combined.dropna()

# %%
def apply_labels_to_df(df, session) -> pd.DataFrame:
    """add labels to dataframe based on bout annotations"""
    if df.empty:
        return df
    
    bout_starts = []
    bout_ends = []

    for bout in session.get('bouts', []):
        if bout.get('label') in LABEL:
            bout_starts.append(bout['start_time'])
            bout_ends.append(bout['end_time'])

    df['label'] = 0

    for start, stop in zip(bout_starts, bout_ends):
        mask = (df['ns_since_reboot'] >= start) & (df['ns_since_reboot'] <= stop)
        df.loc[mask, 'label'] = LABEL_VALUE
    
    return df

# %%
def create_windows(df):
    """create sliding windows from dataframe"""
    if len(df) < WINDOW_SIZE:
        print(f"Warning: DataFrame too small ({len(df)} < {WINDOW_SIZE}), skipping")
        return np.array([]), np.array([])
    
    if USE_GYRO:
        feature_cols = ['x_accel', 'y_accel', 'z_accel', 'x_gyro', 'y_gyro', 'z_gyro']
    else:
        feature_cols = ['x_accel', 'y_accel', 'z_accel']
        
    X_data = df[feature_cols].values
    y_data = df['label'].values
    
    windows_X = []
    windows_y = []
    
    for i in range(0, len(df) - WINDOW_SIZE + 1, STEP_SIZE):
        window_X = X_data[i:i + WINDOW_SIZE]
        window_y = y_data[i:i + WINDOW_SIZE]
        
        windows_X.append(window_X)
        windows_y.append(window_y)
    
    return np.array(windows_X), np.array(windows_y)

# %%
def filter_negative_windows(X, y) :
    """sample negative windows based on configured percentage"""
    if PERCENT_OF_NEGATIVE_WINDOWS_TO_SAMPLE >= 1.0:
        return X, y
    
    # find windows with and without labels
    has_label = np.any(y > 0, axis=1)
    print(f'Positive samples: {np.where(has_label)[0].shape} : Negative Samples  {np.where(~has_label)[0].shape}')
    positive_indices = np.where(has_label)[0]
    negative_indices = np.where(~has_label)[0]
    
    # sample negative windows
    num_negative_to_keep = int(len(negative_indices) * PERCENT_OF_NEGATIVE_WINDOWS_TO_SAMPLE)
    np.random.seed(RANDOM_SEED)
    sampled_negative_indices = np.random.choice(negative_indices, size=num_negative_to_keep, replace=False)
    
    # combine positive and sampled negative windows
    keep_indices = np.concatenate([positive_indices, sampled_negative_indices])
    keep_indices = np.sort(keep_indices)
    
    return X[keep_indices], y[keep_indices]

# %%
def process_session(session, project_path) :
    """process a single session and return windowed data"""
    df = combine(session, project_path)

    # sample_interval = df['ns_since_reboot'].diff().median() * 1e-9
    # sample_rate = 1 / sample_interval
    # print(f"Sample rate: {sample_rate} Hz")

    if df.empty:
        return np.array([]), np.array([])
    
    # check for gaps and split if necessary
    segments = check_for_gaps(df)
    
    all_windows_X = []
    all_windows_y = []
    
    for segment in segments:
        if RESAMPLE:
            segment = resample(segment)
        
        segment = apply_labels_to_df(segment, session)
        windows_X, windows_y = create_windows(segment)
        
        if len(windows_X) > 0:
            all_windows_X.append(windows_X)
            all_windows_y.append(windows_y)
    
    if not all_windows_X:
        return np.array([]), np.array([])
    
    # concatenate all segments
    combined_X = np.concatenate(all_windows_X, axis=0)
    combined_y = np.concatenate(all_windows_y, axis=0)
    
    return combined_X, combined_y

# %%
def make_dataset(sessions_to_use):
    """create dataset from participant ids"""
    all_X = []
    all_y = []
    
    for session, _, project_path in sessions_to_use:
        if session in sessions_to_use:
            X, y = process_session(session, project_path)

        if len(X) > 0:
            all_X.append(X)
            all_y.append(y)
        
    
    if not all_X:
        return np.array([]), np.array([])
    
    # concatenate all participants
    dataset_X = np.concatenate(all_X, axis=0)
    dataset_y = np.concatenate(all_y, axis=0)
    
    # filter negative windows
    dataset_X, dataset_y = filter_negative_windows(dataset_X, dataset_y)
    
    # shuffle the dataset
    np.random.seed(RANDOM_SEED)
    indices = np.random.permutation(len(dataset_X))
    dataset_X = dataset_X[indices]
    dataset_y = dataset_y[indices]
    
    print(f"Dataset created with {len(dataset_X):,} windows")
    
    return dataset_X, dataset_y

# %%
def split_sessions(all_sessions):
    all_sessions = np.array(all_sessions)
    np.random.seed(RANDOM_SEED)
    random_perm = np.random.permutation(len(all_sessions))

    train_size = int(len(random_perm) * TRAIN_PERCENT)
    if TEST_PERCENT > 0:
        dev_size = int(len(random_perm) * DEV_PERCENT)
    else:
        dev_size = len(random_perm) - train_size

    train_idxs = random_perm[:train_size]
    dev_idxs = random_perm[train_size:train_size + dev_size]
    test_idxs = random_perm[train_size + dev_size:]
    
    print(f'TRAIN size: {len(train_idxs)}')
    print(f'DEV size: {len(dev_idxs)}')
    print(f'TEST size: {len(test_idxs)}')
    train, dev, test = all_sessions[train_idxs], all_sessions[dev_idxs], all_sessions[test_idxs]


    def add_session_details_to_list(sessions, maping_list):
        try:
            for session, project_info, _ in sessions:
                session_meta_data  = f"{project_info}_{session['session_name']}"
                maping_list.append(session_meta_data)
        except Exception as e:
            print(f"Error in processing the sessin details: {e}")

    add_session_details_to_list(train, train_sessions)
    add_session_details_to_list(dev, dev_sessions)
    add_session_details_to_list(test, test_sessions)

    return train, dev, test

# %%
def get_all_sessions(labels_data):
    all_sessions = [] # list of tuples with session ifo and project id
    for project in labels_data['projects']:
        participant_code_and_id = f'{project['project_name']}_{project['participant']['participant_code']}_{project['participant']['participant_id']}'
        for session in project['sessions']:
            # if session['bout_count'] > 0:
            lables_present = set()
            for bout in session['bouts']:
                lables_present.add(bout['label'])

            if LABEL.intersection(lables_present):
                all_sessions.append((session, participant_code_and_id, project['project_path']))

    return all_sessions

# %%
def save_dataset(X: np.ndarray, y: np.ndarray, name: str):
    """save X and y tensors in a .pt file with the name as name.pt"""
    if len(X) == 0:
        print(f"Warning: No data to save for {name}")
        return
    
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32)
    
    # transpose X to have shape (batch_size, features, time_steps)
    X_tensor = X_tensor.transpose(1, 2)
    
    save_path = os.path.join(SAVE_DIR, f"{name}.pt")
    torch.save((X_tensor, y_tensor), save_path)
    print(f"Saved {name} dataset with shape X: {X_tensor.shape}, y: {y_tensor.shape}\n\n")

# %%
"""main execution function"""

# validate configuration
validate_splits()

# load labels data
with open(LABELS_PATH, 'r') as f:
    labels_data = json.load(f)

all_sessions = get_all_sessions(labels_data)

train_data, dev_data, test_data = split_sessions(all_sessions)

# create and save datasets
print("\n\nCreating training dataset...")
train_X, train_y = make_dataset(train_data)
save_dataset(train_X, train_y, "train")

print("Creating development dataset...")
dev_X, dev_y = make_dataset(dev_data)
save_dataset(dev_X, dev_y, "dev")

print("Creating test dataset...")
test_X, test_y = make_dataset(test_data)
save_dataset(test_X, test_y, "test")

# save configuration
save_config()
# Out:
# TRAIN size: 43
# DEV size: 11
# TEST size: 0
#
#
# Creating training dataset...
# Positive samples: (2072,) : Negative Samples  (65222,)
# Dataset created with 54,249 windows
# Saved train dataset with shape X: torch.Size([54249, 3, 512]), y: torch.Size([54249, 512])
#
#
# Creating development dataset...
# Positive samples: (626,) : Negative Samples  (19853,)
# Dataset created with 16,508 windows
# Saved dev dataset with shape X: torch.Size([16508, 3, 512]), y: torch.Size([16508, 512])
#
#
# Creating test dataset...
# Warning: No data to save for test

# %%
labels_data
# Out:
# {'export_timestamp': '2025-07-15T18:09:21.018811',
#  'projects': [{'participant': {'participant_code': 'P001',
#     'participant_id': 7},
#    'project_id': 20,
#    'project_name': 'P001 Phase 1',
#    'project_path': '/var/lib/delta/data/P001 Phase 1_P001_20250708_174736',
#    'session_count': 10,
#    'sessions': [{'bout_count': 3,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 290390992835.2031,
#        'duration_seconds': 290.3909928352031,
#        'end_time': 38998321432958.03,
#        'label': 'smoking',
#        'start_time': 38707930440122.83},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 278861821903.78125,
#        'duration_seconds': 278.8618219037813,
#        'end_time': 38994238184919.82,
#        'label': 'andrew smoking',
#        'start_time': 38715376363016.04},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 287825525041,
#        'duration_seconds': 287.825525041,
#        'end_time': 39000182746365,
#        'label': 'andrew smoking labels',
#        'start_time': 38712357221324}],
#      'session_id': 467,
#      'session_name': '2024-06-05_16_12_56.1',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 6,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 538674504389.0703,
#        'duration_seconds': 538.6745043890703,
#        'end_time': 60204077082686.85,
#        'label': 'andrew smoking',
#        'start_time': 59665402578297.78},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 227461495669.58594,
#        'duration_seconds': 227.46149566958593,
#        'end_time': 60873137465346.78,
#        'label': 'andrew smoking',
#        'start_time': 60645675969677.195},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 249239855467.98438,
#        'duration_seconds': 249.23985546798437,
#        'end_time': 60886589289929.03,
#        'label': 'smoking',
#        'start_time': 60637349434461.05},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 567840037687,
#        'duration_seconds': 567.840037687,
#        'end_time': 60208992251668.98,
#        'label': 'smoking',
#        'start_time': 59641152213981.98},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 260565193222,
#        'duration_seconds': 260.565193222,
#        'end_time': 60879919207591,
#        'label': 'andrew smoking labels',
#        'start_time': 60619354014369},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 548943525045,
#        'duration_seconds': 548.943525045,
#        'end_time': 60205151172744,
#        'label': 'andrew smoking labels',
#        'start_time': 59656207647699}],
#      'session_id': 469,
#      'session_name': '2024-06-05_16_12_56.3',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 5,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 345249600000,
#        'duration_seconds': 345.2496,
#        'end_time': 4588916287813,
#        'label': 'andrew smoking',
#        'start_time': 4243666687813},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 334947909736.9839,
#        'duration_seconds': 334.9479097369839,
#        'end_time': 4583202030085.577,
#        'label': 'smoking',
#        'start_time': 4248254120348.5933},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 257948981469.74402,
#        'duration_seconds': 257.948981469744,
#        'end_time': 982355979427.2009,
#        'label': 'smoking',
#        'start_time': 724406997957.4569},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 251243941842,
#        'duration_seconds': 251.243941842,
#        'end_time': 980486397415,
#        'label': 'andrew smoking labels',
#        'start_time': 729242455573},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 345249600000,
#        'duration_seconds': 345.2496,
#        'end_time': 4588916287813,
#        'label': 'andrew smoking labels',
#        'start_time': 4243666687813}],
#      'session_id': 319,
#      'session_name': '2024-06-06_01_09_29',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 6,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 296245700000,
#        'duration_seconds': 296.2457,
#        'end_time': 521670853665,
#        'label': 'smoking',
#        'start_time': 225425153665},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 273255700000,
#        'duration_seconds': 273.2557,
#        'end_time': 20528848353665,
#        'label': 'smoking',
#        'start_time': 20255592653665},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 528090600000,
#        'duration_seconds': 528.0906,
#        'end_time': 21643266753665,
#        'label': 'smoking',
#        'start_time': 21115176153665},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 296245700000,
#        'duration_seconds': 296.2457,
#        'end_time': 521670853665,
#        'label': 'andrew smoking labels',
#        'start_time': 225425153665},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 273255700000,
#        'duration_seconds': 273.2557,
#        'end_time': 20528848353665,
#        'label': 'andrew smoking labels',
#        'start_time': 20255592653665},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 528090600000,
#        'duration_seconds': 528.0906,
#        'end_time': 21643266753665,
#        'label': 'andrew smoking labels',
#        'start_time': 21115176153665}],
#      'session_id': 320,
#      'session_name': '2024-06-06_17_49_48',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 3,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 880539662085.8281,
#        'duration_seconds': 880.5396620858281,
#        'end_time': 75990868254635.42,
#        'label': 'smoking',
#        'start_time': 75110328592549.6},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 154945550225.40625,
#        'duration_seconds': 154.94555022540624,
#        'end_time': 46569732355033.51,
#        'label': 'smoking',
#        'start_time': 46414786804808.1},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 297874914923.1328,
#        'duration_seconds': 297.8749149231328,
#        'end_time': 47335606074719.11,
#        'label': 'smoking',
#        'start_time': 47037731159795.98}],
#      'session_id': 321,
#      'session_name': '2024-06-07_15_08_11',
#      'status': 'Visualized',
#      'verified': False},
#     {'bout_count': 2,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 1627340839303.9917,
#        'duration_seconds': 1627.3408393039917,
#        'end_time': 2126275864892.528,
#        'label': 'smoking',
#        'start_time': 498935025588.5363},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 337032310178,
#        'duration_seconds': 337.032310178,
#        'end_time': 861792084006,
#        'label': 'andrew smoking labels',
#        'start_time': 524759773828}],
#      'session_id': 322,
#      'session_name': '2024-06-08_02_39_41',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 3,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 457531100000,
#        'duration_seconds': 457.5311,
#        'end_time': 66164904742805,
#        'label': 'smoking',
#        'start_time': 65707373642805},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 758278500000,
#        'duration_seconds': 758.2785,
#        'end_time': 68794285442805,
#        'label': 'smoking',
#        'start_time': 68036006942805},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 290041600000,
#        'duration_seconds': 290.0416,
#        'end_time': 80935396242805,
#        'label': 'smoking',
#        'start_time': 80645354642805}],
#      'session_id': 323,
#      'session_name': '2024-06-08_14_04_36',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 9,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 586203100000,
#        'duration_seconds': 586.2031,
#        'end_time': 7492391637706,
#        'label': 'smoking',
#        'start_time': 6906188537706},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 259947500000,
#        'duration_seconds': 259.9475,
#        'end_time': 12384841337706,
#        'label': 'smoking',
#        'start_time': 12124893837706},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 313251100000,
#        'duration_seconds': 313.2511,
#        'end_time': 31023916237706,
#        'label': 'smoking',
#        'start_time': 30710665137706},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 1107510000000,
#        'duration_seconds': 1107.51,
#        'end_time': 33188197637706,
#        'label': 'smoking',
#        'start_time': 32080687637706},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 586203100000,
#        'duration_seconds': 586.2031,
#        'end_time': 7492391637706,
#        'label': 'andrew smoking labels',
#        'start_time': 6906188537706},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 259947500000,
#        'duration_seconds': 259.9475,
#        'end_time': 12384841337706,
#        'label': 'andrew smoking labels',
#        'start_time': 12124893837706},
#       {'bout_index': 6,
#        'confidence': None,
#        'duration_ns': 479460571405,
#        'duration_seconds': 479.460571405,
#        'end_time': 2246307343440,
#        'label': 'andrew smoking labels',
#        'start_time': 1766846772035},
#       {'bout_index': 7,
#        'confidence': None,
#        'duration_ns': 313251100000,
#        'duration_seconds': 313.2511,
#        'end_time': 31023916237706,
#        'label': 'andrew smoking labels',
#        'start_time': 30710665137706},
#       {'bout_index': 8,
#        'confidence': None,
#        'duration_ns': 289149730792,
#        'duration_seconds': 289.149730792,
#        'end_time': 32367461341942,
#        'label': 'andrew smoking labels',
#        'start_time': 32078311611150}],
#      'session_id': 324,
#      'session_name': '2024-06-09_14_35_11',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 0,
#      'bouts': [],
#      'session_id': 325,
#      'session_name': '2024-06-10_15_52_44',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 2,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 279597539729.01825,
#        'duration_seconds': 279.59753972901825,
#        'end_time': 338795806057.2283,
#        'label': 'smoking',
#        'start_time': 59198266328.21004},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 278562197092,
#        'duration_seconds': 278.562197092,
#        'end_time': 334564200323,
#        'label': 'andrew smoking labels',
#        'start_time': 56002003231}],
#      'session_id': 326,
#      'session_name': '2024-06-10_23_55_26',
#      'status': 'Visualized',
#      'verified': True}],
#    'total_bouts': 39},
#   {'participant': {'participant_code': 'P001', 'participant_id': 7},
#    'project_id': 19,
#    'project_name': 'P001 Phase 2',
#    'project_path': '/var/lib/delta/data/P001 Phase 2_P001_20250708_174621',
#    'session_count': 8,
#    'sessions': [{'bout_count': 31,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 268811900000,
#        'duration_seconds': 268.8119,
#        'end_time': 43023279262509,
#        'label': 'smoking',
#        'start_time': 42754467362509},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 369364600000,
#        'duration_seconds': 369.3646,
#        'end_time': 52815393562509,
#        'label': 'smoking',
#        'start_time': 52446028962509},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 334835000000,
#        'duration_seconds': 334.835,
#        'end_time': 70372737162509,
#        'label': 'smoking',
#        'start_time': 70037902162509},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 5526063333.0078125,
#        'duration_seconds': 5.526063333007812,
#        'end_time': 42825404488098.09,
#        'label': 'puffs',
#        'start_time': 42819878424765.086},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 5287699062.1953125,
#        'duration_seconds': 5.287699062195313,
#        'end_time': 42834726302082.05,
#        'label': 'puffs',
#        'start_time': 42829438603019.85},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 4637946011.6328125,
#        'duration_seconds': 4.637946011632812,
#        'end_time': 42849284976072.87,
#        'label': 'puffs',
#        'start_time': 42844647030061.234},
#       {'bout_index': 6,
#        'confidence': None,
#        'duration_ns': 5230024225.875,
#        'duration_seconds': 5.230024225875,
#        'end_time': 42864975048750.51,
#        'label': 'puffs',
#        'start_time': 42859745024524.63},
#       {'bout_index': 7,
#        'confidence': None,
#        'duration_ns': 4144547499.75,
#        'duration_seconds': 4.14454749975,
#        'end_time': 42877408691249.77,
#        'label': 'puffs',
#        'start_time': 42873264143750.02},
#       {'bout_index': 8,
#        'confidence': None,
#        'duration_ns': 5723422737.7578125,
#        'duration_seconds': 5.723422737757812,
#        'end_time': 42888164778808.664,
#        'label': 'puffs',
#        'start_time': 42882441356070.91},
#       {'bout_index': 9,
#        'confidence': None,
#        'duration_ns': 6019461844.8828125,
#        'duration_seconds': 6.019461844882812,
#        'end_time': 42901782577736.43,
#        'label': 'puffs',
#        'start_time': 42895763115891.55},
#       {'bout_index': 10,
#        'confidence': None,
#        'duration_ns': 5230024225.8828125,
#        'duration_seconds': 5.230024225882812,
#        'end_time': 42922209276128.08,
#        'label': 'puffs',
#        'start_time': 42916979251902.195},
#       {'bout_index': 11,
#        'confidence': None,
#        'duration_ns': 5723422737.7578125,
#        'duration_seconds': 5.723422737757812,
#        'end_time': 42937603309698.59,
#        'label': 'puffs',
#        'start_time': 42931879886960.836},
#       {'bout_index': 12,
#        'confidence': None,
#        'duration_ns': 4933985118.7578125,
#        'duration_seconds': 4.933985118757812,
#        'end_time': 42948063358150.36,
#        'label': 'puffs',
#        'start_time': 42943129373031.6},
#       {'bout_index': 13,
#        'confidence': None,
#        'duration_ns': 11052126666.015625,
#        'duration_seconds': 11.052126666015624,
#        'end_time': 42962174555590,
#        'label': 'puffs',
#        'start_time': 42951122428923.984},
#       {'bout_index': 14,
#        'confidence': None,
#        'duration_ns': 4045867797.375,
#        'duration_seconds': 4.045867797375,
#        'end_time': 42971253088208.51,
#        'label': 'puffs',
#        'start_time': 42967207220411.13},
#       {'bout_index': 15,
#        'confidence': None,
#        'duration_ns': 9275892023.257812,
#        'duration_seconds': 9.275892023257812,
#        'end_time': 42983193332195.9,
#        'label': 'puffs',
#        'start_time': 42973917440172.64},
#       {'bout_index': 16,
#        'confidence': None,
#        'duration_ns': 5427383630.6328125,
#        'duration_seconds': 5.4273836306328125,
#        'end_time': 42786129966552.8,
#        'label': 'puffs',
#        'start_time': 42780702582922.164},
#       {'bout_index': 17,
#        'confidence': None,
#        'duration_ns': 5427383630.6328125,
#        'duration_seconds': 5.4273836306328125,
#        'end_time': 42793136225421.43,
#        'label': 'puffs',
#        'start_time': 42787708841790.8},
#       {'bout_index': 18,
#        'confidence': None,
#        'duration_ns': 7598337082.8828125,
#        'duration_seconds': 7.5983370828828125,
#        'end_time': 42806951383753.945,
#        'label': 'puffs',
#        'start_time': 42799353046671.06},
#       {'bout_index': 19,
#        'confidence': None,
#        'duration_ns': 11942103758.945312,
#        'duration_seconds': 11.942103758945313,
#        'end_time': 52779768978344.41,
#        'label': 'puffs',
#        'start_time': 52767826874585.46},
#       {'bout_index': 20,
#        'confidence': None,
#        'duration_ns': 7585542301.8125,
#        'duration_seconds': 7.5855423018125,
#        'end_time': 52758806229686,
#        'label': 'puffs',
#        'start_time': 52751220687384.19},
#       {'bout_index': 21,
#        'confidence': None,
#        'duration_ns': 4664083442.3359375,
#        'duration_seconds': 4.664083442335937,
#        'end_time': 52741328730193.3,
#        'label': 'puffs',
#        'start_time': 52736664646750.96},
#       {'bout_index': 22,
#        'confidence': None,
#        'duration_ns': 5996678711.5703125,
#        'duration_seconds': 5.996678711570312,
#        'end_time': 52718930878937.25,
#        'label': 'puffs',
#        'start_time': 52712934200225.68},
#       {'bout_index': 23,
#        'confidence': None,
#        'duration_ns': 5586649397.9609375,
#        'duration_seconds': 5.5866493979609375,
#        'end_time': 52709397697395.78,
#        'label': 'puffs',
#        'start_time': 52703811047997.82},
#       {'bout_index': 24,
#        'confidence': None,
#        'duration_ns': 5484142069.5625,
#        'duration_seconds': 5.4841420695625,
#        'end_time': 52699300725548.086,
#        'label': 'puffs',
#        'start_time': 52693816583478.52},
#       {'bout_index': 25,
#        'confidence': None,
#        'duration_ns': 5330381076.953125,
#        'duration_seconds': 5.330381076953125,
#        'end_time': 52685257221556.88,
#        'label': 'puffs',
#        'start_time': 52679926840479.93},
#       {'bout_index': 26,
#        'confidence': None,
#        'duration_ns': 9276913220.46875,
#        'duration_seconds': 9.27691322046875,
#        'end_time': 52675877801008.01,
#        'label': 'puffs',
#        'start_time': 52666600887787.54},
#       {'bout_index': 27,
#        'confidence': None,
#        'duration_ns': 6406708025.1796875,
#        'duration_seconds': 6.406708025179688,
#        'end_time': 52656350154947.24,
#        'label': 'puffs',
#        'start_time': 52649943446922.06},
#       {'bout_index': 28,
#        'confidence': None,
#        'duration_ns': 13428460020.789062,
#        'duration_seconds': 13.428460020789062,
#        'end_time': 52645894407450.15,
#        'label': 'puffs',
#        'start_time': 52632465947429.36},
#       {'bout_index': 29,
#        'confidence': None,
#        'duration_ns': 268811900000,
#        'duration_seconds': 268.8119,
#        'end_time': 43023279262509,
#        'label': 'andrew smoking labels',
#        'start_time': 42754467362509},
#       {'bout_index': 30,
#        'confidence': None,
#        'duration_ns': 369364600000,
#        'duration_seconds': 369.3646,
#        'end_time': 52815393562509,
#        'label': 'andrew smoking labels',
#        'start_time': 52446028962509}],
#      'session_id': 309,
#      'session_name': '2024-06-11_09_28_01',
#      'status': 'Visualized',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 311260142603,
#        'duration_seconds': 311.260142603,
#        'end_time': 456045762225,
#        'label': 'andrew smoking labels',
#        'start_time': 144785619622}],
#      'session_id': 310,
#      'session_name': '2024-06-12_00_32_26',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 337852723789,
#        'duration_seconds': 337.852723789,
#        'end_time': 638061396801,
#        'label': 'andrew smoking labels',
#        'start_time': 300208673012}],
#      'session_id': 311,
#      'session_name': '2024-06-12_14_52_11',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 5,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 386662600000,
#        'duration_seconds': 386.6626,
#        'end_time': 21527922561072,
#        'label': 'smoking',
#        'start_time': 21141259961072},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 253200000000,
#        'duration_seconds': 253.2,
#        'end_time': 31616609461072,
#        'label': 'smoking',
#        'start_time': 31363409461072},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 386662600000,
#        'duration_seconds': 386.6626,
#        'end_time': 21527922561072,
#        'label': 'andrew smoking labels',
#        'start_time': 21141259961072},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 290909983009,
#        'duration_seconds': 290.909983009,
#        'end_time': 12081608014437,
#        'label': 'andrew smoking labels',
#        'start_time': 11790698031428},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 244391964401,
#        'duration_seconds': 244.391964401,
#        'end_time': 7771974336737,
#        'label': 'andrew smoking labels',
#        'start_time': 7527582372336}],
#      'session_id': 312,
#      'session_name': '2024-06-12_18_00_33',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 2,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 253200000000,
#        'duration_seconds': 253.2,
#        'end_time': 2359382411615,
#        'label': 'smoking',
#        'start_time': 2106182411615},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 253200000000,
#        'duration_seconds': 253.2,
#        'end_time': 2359382411615,
#        'label': 'andrew smoking labels',
#        'start_time': 2106182411615}],
#      'session_id': 313,
#      'session_name': '2024-06-13_00_36_46',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 14,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 263685600000,
#        'duration_seconds': 263.6856,
#        'end_time': 26377441112995,
#        'label': 'smoking',
#        'start_time': 26113755512995},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 332928700000,
#        'duration_seconds': 332.9287,
#        'end_time': 32097908512995,
#        'label': 'smoking',
#        'start_time': 31764979812995},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 272875000000,
#        'duration_seconds': 272.875,
#        'end_time': 32939301312995,
#        'label': 'smoking',
#        'start_time': 32666426312995},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 277245400000,
#        'duration_seconds': 277.2454,
#        'end_time': 34644983912995,
#        'label': 'smoking',
#        'start_time': 34367738512995},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 309906200000,
#        'duration_seconds': 309.9062,
#        'end_time': 36441095612995,
#        'label': 'smoking',
#        'start_time': 36131189412995},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 255237500000,
#        'duration_seconds': 255.2375,
#        'end_time': 38704606612995,
#        'label': 'smoking',
#        'start_time': 38449369112995},
#       {'bout_index': 6,
#        'confidence': None,
#        'duration_ns': 302411800000,
#        'duration_seconds': 302.4118,
#        'end_time': 45149681412995,
#        'label': 'smoking',
#        'start_time': 44847269612995},
#       {'bout_index': 7,
#        'confidence': None,
#        'duration_ns': 263685600000,
#        'duration_seconds': 263.6856,
#        'end_time': 26377441112995,
#        'label': 'andrew smoking labels',
#        'start_time': 26113755512995},
#       {'bout_index': 8,
#        'confidence': None,
#        'duration_ns': 332928700000,
#        'duration_seconds': 332.9287,
#        'end_time': 32097908512995,
#        'label': 'andrew smoking labels',
#        'start_time': 31764979812995},
#       {'bout_index': 9,
#        'confidence': None,
#        'duration_ns': 272875000000,
#        'duration_seconds': 272.875,
#        'end_time': 32939301312995,
#        'label': 'andrew smoking labels',
#        'start_time': 32666426312995},
#       {'bout_index': 10,
#        'confidence': None,
#        'duration_ns': 277245400000,
#        'duration_seconds': 277.2454,
#        'end_time': 34644983912995,
#        'label': 'andrew smoking labels',
#        'start_time': 34367738512995},
#       {'bout_index': 11,
#        'confidence': None,
#        'duration_ns': 309906200000,
#        'duration_seconds': 309.9062,
#        'end_time': 36441095612995,
#        'label': 'andrew smoking labels',
#        'start_time': 36131189412995},
#       {'bout_index': 12,
#        'confidence': None,
#        'duration_ns': 255237500000,
#        'duration_seconds': 255.2375,
#        'end_time': 38704606612995,
#        'label': 'andrew smoking labels',
#        'start_time': 38449369112995},
#       {'bout_index': 13,
#        'confidence': None,
#        'duration_ns': 302411800000,
#        'duration_seconds': 302.4118,
#        'end_time': 45149681412995,
#        'label': 'andrew smoking labels',
#        'start_time': 44847269612995}],
#      'session_id': 314,
#      'session_name': '2024-06-13_16_09_26',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 266621970921,
#        'duration_seconds': 266.621970921,
#        'end_time': 25870183747980,
#        'label': 'andrew smoking labels',
#        'start_time': 25603561777059}],
#      'session_id': 315,
#      'session_name': '2024-06-14_12_33_15',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 364099641894,
#        'duration_seconds': 364.099641894,
#        'end_time': 70296038461596,
#        'label': 'andrew smoking labels',
#        'start_time': 69931938819702}],
#      'session_id': 316,
#      'session_name': '2024-06-15_13_15_52',
#      'status': 'Initial',
#      'verified': False}],
#    'total_bouts': 56},
#   {'participant': {'participant_code': 'P001', 'participant_id': 7},
#    'project_id': 10,
#    'project_name': 'P001 Phase 3',
#    'project_path': '/var/lib/delta/data/P001 Phase 3_P001_20250707_182055',
#    'session_count': 32,
#    'sessions': [{'bout_count': 0,
#      'bouts': [],
#      'session_id': 204,
#      'session_name': '2025-01-01_10_18_52.1',
#      'status': 'Visualized',
#      'verified': True},
#     {'bout_count': 45,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 359980000000,
#        'duration_seconds': 359.98,
#        'end_time': 101697680000000,
#        'label': 'SmokingCNN',
#        'start_time': 101337700000000},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 4418808565.46875,
#        'duration_seconds': 4.41880856546875,
#        'end_time': 101335923959070.94,
#        'label': 'puffs',
#        'start_time': 101331505150505.47},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 5135372116.625,
#        'duration_seconds': 5.135372116625,
#        'end_time': 101366019628219.56,
#        'label': 'puffs',
#        'start_time': 101360884256102.94},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 5135372116.625,
#        'duration_seconds': 5.135372116625,
#        'end_time': 101385963980393.45,
#        'label': 'puffs',
#        'start_time': 101380828608276.83},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 3463390497.265625,
#        'duration_seconds': 3.463390497265625,
#        'end_time': 101393010188646.52,
#        'label': 'puffs',
#        'start_time': 101389546798149.25},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 3702245014.328125,
#        'duration_seconds': 3.702245014328125,
#        'end_time': 101425016693931.56,
#        'label': 'puffs',
#        'start_time': 101421314448917.23},
#       {'bout_index': 6,
#        'confidence': None,
#        'duration_ns': 5732508409.265625,
#        'duration_seconds': 5.732508409265625,
#        'end_time': 101459053462611.55,
#        'label': 'puffs',
#        'start_time': 101453320954202.28},
#       {'bout_index': 7,
#        'confidence': None,
#        'duration_ns': 4538235824,
#        'duration_seconds': 4.538235824,
#        'end_time': 101484252614160.6,
#        'label': 'puffs',
#        'start_time': 101479714378336.6},
#       {'bout_index': 8,
#        'confidence': None,
#        'duration_ns': 6896991199.40625,
#        'duration_seconds': 6.89699119940625,
#        'end_time': 101533724901177.36,
#        'label': 'puffs',
#        'start_time': 101526827909977.95},
#       {'bout_index': 9,
#        'confidence': None,
#        'duration_ns': 4774840061.125,
#        'duration_seconds': 4.774840061125,
#        'end_time': 101571393083881.78,
#        'label': 'puffs',
#        'start_time': 101566618243820.66},
#       {'bout_index': 10,
#        'confidence': None,
#        'duration_ns': 6012761558.453125,
#        'duration_seconds': 6.012761558453125,
#        'end_time': 101631343853538.11,
#        'label': 'puffs',
#        'start_time': 101625331091979.66},
#       {'bout_index': 11,
#        'confidence': None,
#        'duration_ns': 3549492415.546875,
#        'duration_seconds': 3.549492415546875,
#        'end_time': 101662931528716.1,
#        'label': 'puffs',
#        'start_time': 101659382036300.55},
#       {'bout_index': 12,
#        'confidence': None,
#        'duration_ns': 5135435835.28125,
#        'duration_seconds': 5.13543583528125,
#        'end_time': 101691780594731.9,
#        'label': 'puffs',
#        'start_time': 101686645158896.62},
#       {'bout_index': 13,
#        'confidence': None,
#        'duration_ns': 599980000000,
#        'duration_seconds': 599.98,
#        'end_time': 89157680000000,
#        'label': 'SmokingCNN',
#        'start_time': 88557700000000},
#       {'bout_index': 14,
#        'confidence': None,
#        'duration_ns': 599980000000,
#        'duration_seconds': 599.98,
#        'end_time': 94677680000000,
#        'label': 'SmokingCNN',
#        'start_time': 94077700000000},
#       {'bout_index': 15,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 94857680000000,
#        'label': 'SmokingCNN',
#        'start_time': 94737700000000},
#       {'bout_index': 16,
#        'confidence': None,
#        'duration_ns': 659980000000,
#        'duration_seconds': 659.98,
#        'end_time': 95577680000000,
#        'label': 'SmokingCNN',
#        'start_time': 94917700000000},
#       {'bout_index': 17,
#        'confidence': None,
#        'duration_ns': 419980000000,
#        'duration_seconds': 419.98,
#        'end_time': 96117680000000,
#        'label': 'SmokingCNN',
#        'start_time': 95697700000000},
#       {'bout_index': 18,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 96357680000000,
#        'label': 'SmokingCNN',
#        'start_time': 96237700000000},
#       {'bout_index': 19,
#        'confidence': None,
#        'duration_ns': 239980000000,
#        'duration_seconds': 239.98,
#        'end_time': 96717680000000,
#        'label': 'SmokingCNN',
#        'start_time': 96477700000000},
#       {'bout_index': 20,
#        'confidence': None,
#        'duration_ns': 359980000000,
#        'duration_seconds': 359.98,
#        'end_time': 97197680000000,
#        'label': 'SmokingCNN',
#        'start_time': 96837700000000},
#       {'bout_index': 21,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 98157680000000,
#        'label': 'SmokingCNN',
#        'start_time': 98097700000000},
#       {'bout_index': 22,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 98337680000000,
#        'label': 'SmokingCNN',
#        'start_time': 98217700000000},
#       {'bout_index': 23,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 99117680000000,
#        'label': 'SmokingCNN',
#        'start_time': 98997700000000},
#       {'bout_index': 24,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 99357680000000,
#        'label': 'SmokingCNN',
#        'start_time': 99237700000000},
#       {'bout_index': 25,
#        'confidence': None,
#        'duration_ns': 179980000000,
#        'duration_seconds': 179.98,
#        'end_time': 99597680000000,
#        'label': 'SmokingCNN',
#        'start_time': 99417700000000},
#       {'bout_index': 26,
#        'confidence': None,
#        'duration_ns': 359980000000,
#        'duration_seconds': 359.98,
#        'end_time': 101697680000000,
#        'label': 'SmokingCNN',
#        'start_time': 101337700000000},
#       {'bout_index': 27,
#        'confidence': None,
#        'duration_ns': 599980000000,
#        'duration_seconds': 599.98,
#        'end_time': 89157680000000,
#        'label': 'SmokingCNN',
#        'start_time': 88557700000000},
#       {'bout_index': 28,
#        'confidence': None,
#        'duration_ns': 599980000000,
#        'duration_seconds': 599.98,
#        'end_time': 94677680000000,
#        'label': 'SmokingCNN',
#        'start_time': 94077700000000},
#       {'bout_index': 29,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 94857680000000,
#        'label': 'SmokingCNN',
#        'start_time': 94737700000000},
#       {'bout_index': 30,
#        'confidence': None,
#        'duration_ns': 659980000000,
#        'duration_seconds': 659.98,
#        'end_time': 95577680000000,
#        'label': 'SmokingCNN',
#        'start_time': 94917700000000},
#       {'bout_index': 31,
#        'confidence': None,
#        'duration_ns': 419980000000,
#        'duration_seconds': 419.98,
#        'end_time': 96117680000000,
#        'label': 'SmokingCNN',
#        'start_time': 95697700000000},
#       {'bout_index': 32,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 96357680000000,
#        'label': 'SmokingCNN',
#        'start_time': 96237700000000},
#       {'bout_index': 33,
#        'confidence': None,
#        'duration_ns': 239980000000,
#        'duration_seconds': 239.98,
#        'end_time': 96717680000000,
#        'label': 'SmokingCNN',
#        'start_time': 96477700000000},
#       {'bout_index': 34,
#        'confidence': None,
#        'duration_ns': 359980000000,
#        'duration_seconds': 359.98,
#        'end_time': 97197680000000,
#        'label': 'SmokingCNN',
#        'start_time': 96837700000000},
#       {'bout_index': 35,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 98157680000000,
#        'label': 'SmokingCNN',
#        'start_time': 98097700000000},
#       {'bout_index': 36,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 98337680000000,
#        'label': 'SmokingCNN',
#        'start_time': 98217700000000},
#       {'bout_index': 37,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 99117680000000,
#        'label': 'SmokingCNN',
#        'start_time': 98997700000000},
#       {'bout_index': 38,
#        'confidence': None,
#        'duration_ns': 119980000000,
#        'duration_seconds': 119.98,
#        'end_time': 99357680000000,
#        'label': 'SmokingCNN',
#        'start_time': 99237700000000},
#       {'bout_index': 39,
#        'confidence': None,
#        'duration_ns': 179980000000,
#        'duration_seconds': 179.98,
#        'end_time': 99597680000000,
#        'label': 'SmokingCNN',
#        'start_time': 99417700000000},
#       {'bout_index': 40,
#        'confidence': None,
#        'duration_ns': 359980000000,
#        'duration_seconds': 359.98,
#        'end_time': 101697680000000,
#        'label': 'SmokingCNN',
#        'start_time': 101337700000000},
#       {'bout_index': 41,
#        'confidence': None,
#        'duration_ns': 327501618104,
#        'duration_seconds': 327.501618104,
#        'end_time': 98435337903177,
#        'label': 'andrew smoking labels',
#        'start_time': 98107836285073},
#       {'bout_index': 42,
#        'confidence': None,
#        'duration_ns': 355481594448,
#        'duration_seconds': 355.481594448,
#        'end_time': 98911782214974,
#        'label': 'andrew smoking labels',
#        'start_time': 98556300620526},
#       {'bout_index': 43,
#        'confidence': None,
#        'duration_ns': 191299105605,
#        'duration_seconds': 191.299105605,
#        'end_time': 99573849358420,
#        'label': 'andrew smoking labels',
#        'start_time': 99382550252815},
#       {'bout_index': 44,
#        'confidence': None,
#        'duration_ns': 428913105618,
#        'duration_seconds': 428.913105618,
#        'end_time': 101704053885055,
#        'label': 'andrew smoking labels',
#        'start_time': 101275140779437}],
#      'session_id': 205,
#      'session_name': '2025-01-01_10_18_52.2',
#      'status': 'Visualized',
#      'verified': False},
#     {'bout_count': 85,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 310198458247.04877,
#        'duration_seconds': 310.1984582470488,
#        'end_time': 376330734274.66095,
#        'label': 'smoking',
#        'start_time': 66132276027.6122},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 467890459821.9209,
#        'duration_seconds': 467.8904598219209,
#        'end_time': 1396302603368.5327,
#        'label': 'smoking',
#        'start_time': 928412143546.6118},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 378322475446.8623,
#        'duration_seconds': 378.3224754468623,
#        'end_time': 3243713226400.415,
#        'label': 'smoking',
#        'start_time': 2865390750953.5527},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 572157574749.3525,
#        'duration_seconds': 572.1575747493525,
#        'end_time': 6861948437386.96,
#        'label': 'smoking',
#        'start_time': 6289790862637.607},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 11429763243.036072,
#        'duration_seconds': 11.429763243036072,
#        'end_time': 80220123745.77293,
#        'label': 'puffs',
#        'start_time': 68790360502.73686},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 7708444977.8615265,
#        'duration_seconds': 7.708444977861526,
#        'end_time': 91915695436.32147,
#        'label': 'puffs',
#        'start_time': 84207250458.45995},
#       {'bout_index': 6,
#        'confidence': None,
#        'duration_ns': 8505870320.398941,
#        'duration_seconds': 8.505870320398941,
#        'end_time': 127002410507.9671,
#        'label': 'puffs',
#        'start_time': 118496540187.56816},
#       {'bout_index': 7,
#        'confidence': None,
#        'duration_ns': 5466633537.366974,
#        'duration_seconds': 5.466633537366974,
#        'end_time': 159823284168.20255,
#        'label': 'puffs',
#        'start_time': 154356650630.83557},
#       {'bout_index': 8,
#        'confidence': None,
#        'duration_ns': 5982353682.401581,
#        'duration_seconds': 5.98235368240158,
#        'end_time': 175707464635.26883,
#        'label': 'puffs',
#        'start_time': 169725110952.86725},
#       {'bout_index': 9,
#        'confidence': None,
#        'duration_ns': 4786885258.780182,
#        'duration_seconds': 4.786885258780182,
#        'end_time': 200295107555.27896,
#        'label': 'puffs',
#        'start_time': 195508222296.49878},
#       {'bout_index': 10,
#        'confidence': None,
#        'duration_ns': 6627994973.695618,
#        'duration_seconds': 6.627994973695618,
#        'end_time': 215023985274.60254,
#        'label': 'puffs',
#        'start_time': 208395990300.90692},
#       {'bout_index': 11,
#        'confidence': None,
#        'duration_ns': 3430304148.9459534,
#        'duration_seconds': 3.4303041489459534,
#        'end_time': 220799849531.07742,
#        'label': 'puffs',
#        'start_time': 217369545382.13147},
#       {'bout_index': 12,
#        'confidence': None,
#        'duration_ns': 3053150075.588318,
#        'duration_seconds': 3.053150075588318,
#        'end_time': 250773889447.5171,
#        'label': 'puffs',
#        'start_time': 247720739371.92877},
#       {'bout_index': 13,
#        'confidence': None,
#        'duration_ns': 4471558690.14624,
#        'duration_seconds': 4.4715586901462405,
#        'end_time': 302088248979.0775,
#        'label': 'puffs',
#        'start_time': 297616690288.9313},
#       {'bout_index': 14,
#        'confidence': None,
#        'duration_ns': 4268306022.4122925,
#        'duration_seconds': 4.268306022412292,
#        'end_time': 333998917813.3029,
#        'label': 'puffs',
#        'start_time': 329730611790.8906},
#       {'bout_index': 15,
#        'confidence': None,
#        'duration_ns': 4776437691.747131,
#        'duration_seconds': 4.776437691747131,
#        'end_time': 369873013668.33984,
#        'label': 'puffs',
#        'start_time': 365096575976.5927},
#       {'bout_index': 16,
#        'confidence': None,
#        'duration_ns': 6507516826.452393,
#        'duration_seconds': 6.507516826452393,
#        'end_time': 939078772469.0665,
#        'label': 'puffs',
#        'start_time': 932571255642.6141},
#       {'bout_index': 17,
#        'confidence': None,
#        'duration_ns': 6507516826.452393,
#        'duration_seconds': 6.507516826452393,
#        'end_time': 959035157403.5203,
#        'label': 'puffs',
#        'start_time': 952527640577.0679},
#       {'bout_index': 18,
#        'confidence': None,
#        'duration_ns': 5314472074.936035,
#        'duration_seconds': 5.3144720749360355,
#        'end_time': 969989477394.715,
#        'label': 'puffs',
#        'start_time': 964675005319.7789},
#       {'bout_index': 19,
#        'confidence': None,
#        'duration_ns': 5531389302.484497,
#        'duration_seconds': 5.531389302484497,
#        'end_time': 1011095292015.1387,
#        'label': 'puffs',
#        'start_time': 1005563902712.6542},
#       {'bout_index': 20,
#        'confidence': None,
#        'duration_ns': 5422930688.710205,
#        'duration_seconds': 5.422930688710205,
#        'end_time': 1019121229434.4298,
#        'label': 'puffs',
#        'start_time': 1013698298745.7196},
#       {'bout_index': 21,
#        'confidence': None,
#        'duration_ns': 5251387122.084839,
#        'duration_seconds': 5.2513871220848385,
#        'end_time': 1059982806840.4846,
#        'label': 'puffs',
#        'start_time': 1054731419718.3998},
#       {'bout_index': 22,
#        'confidence': None,
#        'duration_ns': 6418362038.103638,
#        'duration_seconds': 6.418362038103638,
#        'end_time': 1093008196963.818,
#        'label': 'puffs',
#        'start_time': 1086589834925.7144},
#       {'bout_index': 23,
#        'confidence': None,
#        'duration_ns': 5251387122.084717,
#        'duration_seconds': 5.251387122084717,
#        'end_time': 1124049729729.9192,
#        'label': 'puffs',
#        'start_time': 1118798342607.8345},
#       {'bout_index': 24,
#        'confidence': None,
#        'duration_ns': 6651757021.307373,
#        'duration_seconds': 6.651757021307373,
#        'end_time': 1184032240413.2878,
#        'label': 'puffs',
#        'start_time': 1177380483391.9805},
#       {'bout_index': 25,
#        'confidence': None,
#        'duration_ns': 6405315440.395996,
#        'duration_seconds': 6.405315440395996,
#        'end_time': 1225985743408.1047,
#        'label': 'puffs',
#        'start_time': 1219580427967.7087},
#       {'bout_index': 26,
#        'confidence': None,
#        'duration_ns': 4022734568.2973633,
#        'duration_seconds': 4.022734568297364,
#        'end_time': 1230776547602.191,
#        'label': 'puffs',
#        'start_time': 1226753813033.8936},
#       {'bout_index': 27,
#        'confidence': None,
#        'duration_ns': 6280542200.435059,
#        'duration_seconds': 6.280542200435058,
#        'end_time': 1252934013628.3704,
#        'label': 'puffs',
#        'start_time': 1246653471427.9353},
#       {'bout_index': 28,
#        'confidence': None,
#        'duration_ns': 9154688631.142578,
#        'duration_seconds': 9.154688631142578,
#        'end_time': 1267836995120.928,
#        'label': 'puffs',
#        'start_time': 1258682306489.7854},
#       {'bout_index': 29,
#        'confidence': None,
#        'duration_ns': 6280542200.435059,
#        'duration_seconds': 6.280542200435058,
#        'end_time': 1284762524101.7612,
#        'label': 'puffs',
#        'start_time': 1278481981901.3262},
#       {'bout_index': 30,
#        'confidence': None,
#        'duration_ns': 5322493390.198975,
#        'duration_seconds': 5.322493390198975,
#        'end_time': 1290936616434.392,
#        'label': 'puffs',
#        'start_time': 1285614123044.193},
#       {'bout_index': 31,
#        'confidence': None,
#        'duration_ns': 7451490746.278809,
#        'duration_seconds': 7.451490746278808,
#        'end_time': 1306904096604.9897,
#        'label': 'puffs',
#        'start_time': 1299452605858.711},
#       {'bout_index': 32,
#        'confidence': None,
#        'duration_ns': 3619295505.335449,
#        'duration_seconds': 3.619295505335449,
#        'end_time': 1324042525321.431,
#        'label': 'puffs',
#        'start_time': 1320423229816.0955},
#       {'bout_index': 33,
#        'confidence': None,
#        'duration_ns': 4470894447.767334,
#        'duration_seconds': 4.470894447767334,
#        'end_time': 1349058244255.367,
#        'label': 'puffs',
#        'start_time': 1344587349807.5996},
#       {'bout_index': 34,
#        'confidence': None,
#        'duration_ns': 6067642464.826904,
#        'duration_seconds': 6.067642464826904,
#        'end_time': 1361832228391.8447,
#        'label': 'puffs',
#        'start_time': 1355764585927.0178},
#       {'bout_index': 35,
#        'confidence': None,
#        'duration_ns': 4364444579.963379,
#        'duration_seconds': 4.364444579963379,
#        'end_time': 1368964369534.7117,
#        'label': 'puffs',
#        'start_time': 1364599924954.7483},
#       {'bout_index': 36,
#        'confidence': None,
#        'duration_ns': 3832195240.9433594,
#        'duration_seconds': 3.8321952409433595,
#        'end_time': 1390999492170.1362,
#        'label': 'puffs',
#        'start_time': 1387167296929.1929},
#       {'bout_index': 37,
#        'confidence': None,
#        'duration_ns': 359980000000,
#        'duration_seconds': 359.98,
#        'end_time': 423720000000,
#        'label': 'SmokingCNN',
#        'start_time': 63740000000},
#       {'bout_index': 38,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 603720000000,
#        'label': 'SmokingCNN',
#        'start_time': 543740000000},
#       {'bout_index': 39,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 843720000000,
#        'label': 'SmokingCNN',
#        'start_time': 783740000000},
#       {'bout_index': 40,
#        'confidence': None,
#        'duration_ns': 419980000000,
#        'duration_seconds': 419.98,
#        'end_time': 1383720000000,
#        'label': 'SmokingCNN',
#        'start_time': 963740000000},
#       {'bout_index': 41,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 1563720000000,
#        'label': 'SmokingCNN',
#        'start_time': 1503740000000},
#       {'bout_index': 42,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 1743720000000,
#        'label': 'SmokingCNN',
#        'start_time': 1683740000000},
#       {'bout_index': 43,
#        'confidence': None,
#        'duration_ns': 179980000000,
#        'duration_seconds': 179.98,
#        'end_time': 1983720000000,
#        'label': 'SmokingCNN',
#        'start_time': 1803740000000},
#       {'bout_index': 44,
#        'confidence': None,
#        'duration_ns': 59980000000,
#        'duration_seconds': 59.98,
#        'end_time': 2403720000000,
#        'label': 'SmokingCNN',
#        'start_time': 2343740000000},
#       {'bout_index': 45,
#        'confidence': None,
#        'duration_ns': 239980000000,
#        'duration_seconds': 239.98,
#        'end_time': 3243720000000,
#        'label': 'SmokingCNN',
#        'start_time': 3003740000000},
#       {'bout_index': 46,
#        'confidence': None,
#        'duration_ns': 59980000000,
# ...
#        'confidence': None,
#        'duration_ns': 419504000000,
#        'duration_seconds': 419.504,
#        'end_time': 29687269006133,
#        'label': 'smoking',
#        'start_time': 29267765006133},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 439812000000,
#        'duration_seconds': 439.812,
#        'end_time': 30814260006133,
#        'label': 'smoking',
#        'start_time': 30374448006133},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 799067000000,
#        'duration_seconds': 799.067,
#        'end_time': 32261130006133,
#        'label': 'smoking',
#        'start_time': 31462063006133},
#       {'bout_index': 5,
#        'confidence': None,
#        'duration_ns': 1207168000000,
#        'duration_seconds': 1207.168,
#        'end_time': 69191616006133,
#        'label': 'smoking',
#        'start_time': 67984448006133},
#       {'bout_index': 6,
#        'confidence': None,
#        'duration_ns': 1438064000000,
#        'duration_seconds': 1438.064,
#        'end_time': 70815661006133,
#        'label': 'smoking',
#        'start_time': 69377597006133},
#       {'bout_index': 7,
#        'confidence': None,
#        'duration_ns': 467072000000,
#        'duration_seconds': 467.072,
#        'end_time': 73639029006133,
#        'label': 'smoking',
#        'start_time': 73171957006133},
#       {'bout_index': 8,
#        'confidence': None,
#        'duration_ns': 453318000000,
#        'duration_seconds': 453.318,
#        'end_time': 75476691006133,
#        'label': 'smoking',
#        'start_time': 75023373006133},
#       {'bout_index': 9,
#        'confidence': None,
#        'duration_ns': 276103000000,
#        'duration_seconds': 276.103,
#        'end_time': 78415309006133,
#        'label': 'smoking',
#        'start_time': 78139206006133},
#       {'bout_index': 10,
#        'confidence': None,
#        'duration_ns': 578208000000,
#        'duration_seconds': 578.208,
#        'end_time': 2973526006133,
#        'label': 'andrew smoking labels',
#        'start_time': 2395318006133},
#       {'bout_index': 11,
#        'confidence': None,
#        'duration_ns': 418650000000,
#        'duration_seconds': 418.65,
#        'end_time': 27522100006133,
#        'label': 'andrew smoking labels',
#        'start_time': 27103450006133},
#       {'bout_index': 12,
#        'confidence': None,
#        'duration_ns': 419504000000,
#        'duration_seconds': 419.504,
#        'end_time': 29687269006133,
#        'label': 'andrew smoking labels',
#        'start_time': 29267765006133},
#       {'bout_index': 13,
#        'confidence': None,
#        'duration_ns': 439812000000,
#        'duration_seconds': 439.812,
#        'end_time': 30814260006133,
#        'label': 'andrew smoking labels',
#        'start_time': 30374448006133},
#       {'bout_index': 14,
#        'confidence': None,
#        'duration_ns': 799067000000,
#        'duration_seconds': 799.067,
#        'end_time': 32261130006133,
#        'label': 'andrew smoking labels',
#        'start_time': 31462063006133},
#       {'bout_index': 15,
#        'confidence': None,
#        'duration_ns': 1207168000000,
#        'duration_seconds': 1207.168,
#        'end_time': 69191616006133,
#        'label': 'andrew smoking labels',
#        'start_time': 67984448006133},
#       {'bout_index': 16,
#        'confidence': None,
#        'duration_ns': 1438064000000,
#        'duration_seconds': 1438.064,
#        'end_time': 70815661006133,
#        'label': 'andrew smoking labels',
#        'start_time': 69377597006133},
#       {'bout_index': 17,
#        'confidence': None,
#        'duration_ns': 467072000000,
#        'duration_seconds': 467.072,
#        'end_time': 73639029006133,
#        'label': 'andrew smoking labels',
#        'start_time': 73171957006133},
#       {'bout_index': 18,
#        'confidence': None,
#        'duration_ns': 453318000000,
#        'duration_seconds': 453.318,
#        'end_time': 75476691006133,
#        'label': 'andrew smoking labels',
#        'start_time': 75023373006133},
#       {'bout_index': 19,
#        'confidence': None,
#        'duration_ns': 276103000000,
#        'duration_seconds': 276.103,
#        'end_time': 78415309006133,
#        'label': 'andrew smoking labels',
#        'start_time': 78139206006133}],
#      'session_id': 247,
#      'session_name': '2024-11-28_19_50_21',
#      'status': 'Visualized',
#      'verified': False}],
#    'total_bouts': 278},
#   {'participant': {'participant_code': 'Test', 'participant_id': 25},
#    'project_id': 29,
#    'project_name': 'Test1',
#    'project_path': '/var/lib/delta/data/Test1_Test_20250715_132328',
#    'session_count': 17,
#    'sessions': [{'bout_count': 5,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 1829000000,
#        'duration_seconds': 1.829,
#        'end_time': 340134601538821,
#        'label': 'smoking',
#        'start_time': 340132772538821},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 2356000000,
#        'duration_seconds': 2.356,
#        'end_time': 340747289538821,
#        'label': 'smoking',
#        'start_time': 340744933538821},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 297884000000,
#        'duration_seconds': 297.884,
#        'end_time': 341600994538821,
#        'label': 'smoking',
#        'start_time': 341303110538821},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 381143000000,
#        'duration_seconds': 381.143,
#        'end_time': 348529001538821,
#        'label': 'smoking',
#        'start_time': 348147858538821},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 306596000000,
#        'duration_seconds': 306.596,
#        'end_time': 354843165538821,
#        'label': 'smoking',
#        'start_time': 354536569538821}],
#      'session_id': 481,
#      'session_name': '2025-05-12_12_51_29.1',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 4,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 276643000000,
#        'duration_seconds': 276.643,
#        'end_time': 420817589538821,
#        'label': 'smoking',
#        'start_time': 420540946538821},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 753263000000,
#        'duration_seconds': 753.263,
#        'end_time': 425347019538821,
#        'label': 'smoking',
#        'start_time': 424593756538821},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 397473000000,
#        'duration_seconds': 397.473,
#        'end_time': 425748865538821,
#        'label': 'smoking',
#        'start_time': 425351392538821},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 445012000000,
#        'duration_seconds': 445.012,
#        'end_time': 435511838538821,
#        'label': 'smoking',
#        'start_time': 435066826538821}],
#      'session_id': 482,
#      'session_name': '2025-05-12_12_51_29.2',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 4,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 341585000000,
#        'duration_seconds': 341.585,
#        'end_time': 510059715538821,
#        'label': 'smoking',
#        'start_time': 509718130538821},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 297844000000,
#        'duration_seconds': 297.844,
#        'end_time': 514507156538821,
#        'label': 'smoking',
#        'start_time': 514209312538821},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 4783302000000,
#        'duration_seconds': 4783.302,
#        'end_time': 524096200538821,
#        'label': 'smoking',
#        'start_time': 519312898538821},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 352010000000,
#        'duration_seconds': 352.01,
#        'end_time': 524452941538821,
#        'label': 'smoking',
#        'start_time': 524100931538821}],
#      'session_id': 483,
#      'session_name': '2025-05-12_12_51_29.3',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 2,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 421327000000,
#        'duration_seconds': 421.327,
#        'end_time': 597489349538821,
#        'label': 'smoking',
#        'start_time': 597068022538821},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 288706000000,
#        'duration_seconds': 288.706,
#        'end_time': 603898737538821,
#        'label': 'smoking',
#        'start_time': 603610031538821}],
#      'session_id': 484,
#      'session_name': '2025-05-12_12_51_29.4',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 3,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 353362000000,
#        'duration_seconds': 353.362,
#        'end_time': 611198442538821,
#        'label': 'smoking',
#        'start_time': 610845080538821},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 281089000000,
#        'duration_seconds': 281.089,
#        'end_time': 614502997538821,
#        'label': 'smoking',
#        'start_time': 614221908538821},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 230548000000,
#        'duration_seconds': 230.548,
#        'end_time': 617720957538821,
#        'label': 'smoking',
#        'start_time': 617490409538821}],
#      'session_id': 485,
#      'session_name': '2025-05-12_12_51_29.5',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 5,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 253472000000,
#        'duration_seconds': 253.472,
#        'end_time': 678463277538821,
#        'label': 'smoking',
#        'start_time': 678209805538821},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 381763000000,
#        'duration_seconds': 381.763,
#        'end_time': 685103802538821,
#        'label': 'smoking',
#        'start_time': 684722039538821},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 81165000000,
#        'duration_seconds': 81.165,
#        'end_time': 690396203538821,
#        'label': 'smoking',
#        'start_time': 690315038538821},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 542308000000,
#        'duration_seconds': 542.308,
#        'end_time': 692974188538821,
#        'label': 'smoking',
#        'start_time': 692431880538821},
#       {'bout_index': 4,
#        'confidence': None,
#        'duration_ns': 230893000000,
#        'duration_seconds': 230.893,
#        'end_time': 700623845538821,
#        'label': 'smoking',
#        'start_time': 700392952538821}],
#      'session_id': 486,
#      'session_name': '2025-05-12_12_51_29.6',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 0,
#      'bouts': [],
#      'session_id': 487,
#      'session_name': '2025-05-17_09_19_41.1',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 233309000000,
#        'duration_seconds': 233.309,
#        'end_time': 24878540402327,
#        'label': 'smoking',
#        'start_time': 24645231402327}],
#      'session_id': 488,
#      'session_name': '2025-05-17_09_19_41.2',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 4,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 395741000000,
#        'duration_seconds': 395.741,
#        'end_time': 39585975402327,
#        'label': 'smoking',
#        'start_time': 39190234402327},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 498050000000,
#        'duration_seconds': 498.05,
#        'end_time': 44610319402327,
#        'label': 'smoking',
#        'start_time': 44112269402327},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 314618000000,
#        'duration_seconds': 314.618,
#        'end_time': 46340414402327,
#        'label': 'smoking',
#        'start_time': 46025796402327},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 357471597673,
#        'duration_seconds': 357.471597673,
#        'end_time': 50837180000000,
#        'label': 'smoking',
#        'start_time': 50479708402327}],
#      'session_id': 489,
#      'session_name': '2025-05-17_09_19_41.3',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 274685000000,
#        'duration_seconds': 274.685,
#        'end_time': 92025090402327,
#        'label': 'smoking',
#        'start_time': 91750405402327}],
#      'session_id': 490,
#      'session_name': '2025-05-17_09_19_41.4',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 3,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 231701000000,
#        'duration_seconds': 231.701,
#        'end_time': 100121411402327,
#        'label': 'smoking',
#        'start_time': 99889710402327},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 1188022000000,
#        'duration_seconds': 1188.022,
#        'end_time': 108907647402327,
#        'label': 'smoking',
#        'start_time': 107719625402327},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 242253000000,
#        'duration_seconds': 242.253,
#        'end_time': 112494105402327,
#        'label': 'smoking',
#        'start_time': 112251852402327}],
#      'session_id': 491,
#      'session_name': '2025-05-17_09_19_41.5',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 0,
#      'bouts': [],
#      'session_id': 492,
#      'session_name': '2025-05-17_09_19_41.6',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 0,
#      'bouts': [],
#      'session_id': 493,
#      'session_name': '2025-05-18_22_42_40.1',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 0,
#      'bouts': [],
#      'session_id': 494,
#      'session_name': '2025-05-18_22_42_40.2',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 4,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 587505000000,
#        'duration_seconds': 587.505,
#        'end_time': 47280351306235,
#        'label': 'smoking',
#        'start_time': 46692846306235},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 361933000000,
#        'duration_seconds': 361.933,
#        'end_time': 47643459306235,
#        'label': 'smoking',
#        'start_time': 47281526306235},
#       {'bout_index': 2,
#        'confidence': None,
#        'duration_ns': 361660000000,
#        'duration_seconds': 361.66,
#        'end_time': 48658585306235,
#        'label': 'smoking',
#        'start_time': 48296925306235},
#       {'bout_index': 3,
#        'confidence': None,
#        'duration_ns': 421049000000,
#        'duration_seconds': 421.049,
#        'end_time': 52070034306235,
#        'label': 'smoking',
#        'start_time': 51648985306235}],
#      'session_id': 495,
#      'session_name': '2025-05-18_22_42_40.3',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 1,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 227837000000,
#        'duration_seconds': 227.837,
#        'end_time': 310450629358,
#        'label': 'smoking',
#        'start_time': 82613629358}],
#      'session_id': 496,
#      'session_name': '2025-05-19_16_43_28',
#      'status': 'Initial',
#      'verified': False},
#     {'bout_count': 2,
#      'bouts': [{'bout_index': 0,
#        'confidence': None,
#        'duration_ns': 288476000000,
#        'duration_seconds': 288.476,
#        'end_time': 3107077603578,
#        'label': 'smoking',
#        'start_time': 2818601603578},
#       {'bout_index': 1,
#        'confidence': None,
#        'duration_ns': 1025317000000,
#        'duration_seconds': 1025.317,
#        'end_time': 5863713603578,
#        'label': 'smoking',
#        'start_time': 4838396603578}],
#      'session_id': 497,
#      'session_name': '2025-05-20_10_54_16',
#      'status': 'Initial',
#      'verified': False}],
#    'total_bouts': 39}],
#  'success': True,
#  'total_labels': 4502,
#  'total_projects': 22,
#  'total_sessions': 363}
